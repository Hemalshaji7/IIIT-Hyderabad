# %%
import tensorflow as tf
import os
from os.path import isfile, join
import numpy as np
import shutil
from tensorflow import keras
from pathlib import Path
from IPython.display import display, Audio
import subprocess
import random

# %% [markdown]
# Mounting google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !cp -r "../content/gdrive/MyDrive/speaker-recognition-dataset" ./

# %% [markdown]
# Getting data directories

# %%
data_directory = "./speaker-recognition-dataset/16000_pcm_speeches"
audio_folder = "audio"
noise_folder = "noise"

audio_path = os.path.join(data_directory, audio_folder)
noise_path = os.path.join(data_directory, noise_folder)

# %%
audio_path
# Out:
# './speaker-recognition-dataset/16000_pcm_speeches/audio'

# %%
valid_split = 0.1

shuffle_seed = 43

sample_rate = 16000

scale = 0.5

batch_size = 64

epochs = 10

# %% [markdown]
# Arrange audio and noise

# %%
for folder in os.listdir(data_directory):
    if os.path.isdir(os.path.join(data_directory, folder)):
        if folder in [audio_folder, noise_folder]:

            continue
        elif folder in ["other", "_background_noise_"]:

            shutil.move(
                os.path.join(data_directory, folder),
                os.path.join(noise_path, folder),
            )
        else:
            shutil.move(
                os.path.join(data_directory, folder),
                os.path.join(audio_path, folder),
            )

# %%
noise_paths = []
for subdir in os.listdir(noise_path):
    subdir_path = Path(noise_path) / subdir
    if os.path.isdir(subdir_path):
        noise_paths += [
            os.path.join(subdir_path, filepath)
            for filepath in os.listdir(subdir_path)
            if filepath.endswith(".wav")
        ]

# %%
noise_paths
# Out:
# ['speaker-recognition-dataset/16000_pcm_speeches/noise/other/exercise_bike.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/noise/other/pink_noise.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/noise/_background_noise_/dude_miaowing.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/noise/_background_noise_/10convert.com_Audience-Claps_daSG5fwdA7o.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/noise/_background_noise_/doing_the_dishes.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/noise/_background_noise_/running_tap.wav']

# %%
command = (
    "for dir in `ls -1 " + noise_path + "`; do "
    "for file in `ls -1 " + noise_path + "/$dir/*.wav`; do "
    "sample_rate=`ffprobe -hide_banner -loglevel panic -show_streams "
    "$file | grep sample_rate | cut -f2 -d=`; "
    "if [ $sample_rate -ne 16000 ]; then "
    "ffmpeg -hide_banner -loglevel panic -y "
    "-i $file -ar 16000 temp.wav; "
    "mv temp.wav $file; "
    "fi; done; done"
)

# %%
os.system(command)
def load_noise_sample(path):
    sample, sampling_rate = tf.audio.decode_wav(
        tf.io.read_file(path), desired_channels=1
    )
    if sampling_rate == sample_rate:
        slices = int(sample.shape[0] / sample_rate)
        sample = tf.split(sample[: slices * sample_rate], slices)
        return sample
    else:
        print("Sampling rate for",path, "is incorrect")
        return None

# %% [markdown]
# Selecting portion of dataset for training

# %%
# Define the percentage of data to use (e.g., 50%)
subset_percentage = 0.5

# Get a list of all noise files
all_noise_files = []
for dirpath, dirnames, filenames in os.walk(noise_path):
    for filename in filenames:
        if filename.endswith('.wav'):
            all_noise_files.append(os.path.join(dirpath, filename))

# Randomly select a subset of noise files
subset_size = int(len(all_noise_files) * subset_percentage)
selected_noise_files = random.sample(all_noise_files, subset_size)

# Load only the selected noise files
noises = []
for path in selected_noise_files:
    sample = load_noise_sample(path)
    if sample:
        noises.extend(sample)
noises = tf.stack(noises)

# %%
speaker_paths = [
    os.path.join(audio_path, speaker)
    for speaker in os.listdir(audio_path)
    if os.path.isdir(os.path.join(audio_path, speaker))
]

def get_audio_files(folder):
    audio_files = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith(".wav"):
                audio_files.append(os.path.join(root, file))
    return audio_files

# %%
samples_per_speaker = 500  # Adjust as needed

# Get a list of all audio files for each speaker
selected_speaker_files = []

for speaker_path in speaker_paths:
    audio_files = get_audio_files(speaker_path)
    random.shuffle(audio_files)

    # Remove './' prefix from each path
    audio_files = [path[2:] if path.startswith("./") else path for path in audio_files]

    # Extend selected_speaker_files with modified paths
    selected_speaker_files.extend(audio_files[:samples_per_speaker])

# %%
selected_speaker_files
# Out:
# ['speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1282.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/95.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1184.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/803.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1159.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1331.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/476.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/832.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/791.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1027.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1471.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/174.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1324.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/270.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1360.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1168.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/992.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/576.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/563.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/279.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1463.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/170.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/650.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1298.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/959.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1494.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1194.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/880.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1106.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/896.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1016.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/690.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1319.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/607.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/739.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/686.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1336.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1112.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/804.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/784.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/77.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1437.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1317.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/591.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/601.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/745.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/403.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1220.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/625.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/657.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/479.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1140.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/856.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1446.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1051.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/637.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1389.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1081.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1250.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/787.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/38.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/765.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/407.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/208.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/593.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/735.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/546.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/53.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/932.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1357.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1342.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/831.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/338.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/47.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1030.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/261.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/162.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/782.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/346.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1277.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/661.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/436.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/166.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/54.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/634.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1280.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/210.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/908.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/381.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/312.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/571.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1448.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1475.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1146.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1186.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/821.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/999.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/687.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1124.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1352.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/328.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/857.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/251.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1498.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/416.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/22.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/387.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1131.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/456.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/342.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1262.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/224.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1383.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/445.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/219.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1419.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1367.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/396.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/71.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/677.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/636.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/432.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/757.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/987.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/184.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/115.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/8.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/897.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/685.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/406.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1127.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/810.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/551.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/298.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1247.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1266.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/718.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/484.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/909.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/81.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/49.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/595.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1368.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/736.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/68.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/440.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1472.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/755.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1086.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/572.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1379.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1447.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/272.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1334.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/513.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/459.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1151.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/524.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1043.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/343.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/849.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/582.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/594.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/226.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/60.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/705.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/57.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/329.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/301.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1307.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1110.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/466.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1457.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1299.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/748.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/309.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/906.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/644.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/304.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/104.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1071.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/136.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1445.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/108.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/169.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/864.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1402.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1289.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/348.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1321.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/860.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/876.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1174.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/589.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/807.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1206.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/658.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1441.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/549.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/629.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/382.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1382.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/84.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/211.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1115.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/680.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/350.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/451.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/43.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/280.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/558.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/569.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/218.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/377.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/681.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1385.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1290.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/564.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/852.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/756.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1173.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1180.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/222.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/78.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/758.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/230.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/293.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1088.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1153.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/194.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/206.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/976.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1064.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/531.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1288.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/697.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/788.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/963.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1035.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/411.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/870.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1465.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1394.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1133.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/368.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/713.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/499.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/433.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/892.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/602.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/52.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/404.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1162.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/150.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/66.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/468.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1120.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1014.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/109.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/969.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1019.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/300.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/492.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/148.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/781.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/667.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/545.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/579.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1430.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/284.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/311.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/332.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/40.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1228.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/156.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/984.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/948.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/185.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/88.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/356.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1195.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/429.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/577.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/76.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/116.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/983.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1217.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/398.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/new.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/732.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/344.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1196.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/405.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/59.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/666.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1432.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/923.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/367.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/711.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/242.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/489.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1366.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/648.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/985.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/903.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/640.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/929.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/631.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/290.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/402.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/67.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/819.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/90.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/421.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/624.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/308.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/953.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1128.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1054.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/439.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/934.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1192.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/498.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/229.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/779.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1407.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/621.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/497.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1033.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/560.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/512.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/101.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/334.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/721.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/216.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/124.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/893.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1236.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/668.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/395.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/373.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/335.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/33.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/886.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/516.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/638.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1392.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/846.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/163.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1396.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/945.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/485.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/740.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1067.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1451.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/228.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/719.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/30.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/474.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1085.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/598.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/767.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/246.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1161.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1244.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/408.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/927.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1121.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1069.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/809.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/842.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/65.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1008.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1078.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1487.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1235.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/271.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1001.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/441.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/345.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/10.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/957.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/125.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1409.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1004.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/375.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/144.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1000.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/351.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/168.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/253.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/370.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/240.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1185.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/413.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/974.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1009.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/768.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/507.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/238.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/120.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/422.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1210.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1320.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1359.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/965.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/2.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/703.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/188.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/51.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1102.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/233.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/656.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/369.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/774.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1020.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/622.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/603.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/257.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1152.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/565.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/154.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/590.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/553.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/426.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/806.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1330.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/141.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/643.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/145.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/676.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/574.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1381.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1386.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/415.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/635.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1483.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/223.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/950.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1401.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/592.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/6.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/780.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1484.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/15.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1197.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/960.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1026.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1370.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/539.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/363.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/263.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/478.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/862.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/105.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/905.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/427.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1285.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1375.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1482.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/778.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/316.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/5.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1077.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/536.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/561.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/209.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/707.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1148.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/609.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/371.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/751.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/922.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/520.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1461.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1287.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/282.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1404.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/817.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/202.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1048.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/844.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1259.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1005.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/502.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1239.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/813.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1444.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/538.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1411.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1308.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1351.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1191.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/828.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/747.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1414.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1270.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/1029.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/118.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Julia_Gillard/16.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1002.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/703.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/900.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/389.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/819.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/870.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/984.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1425.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1156.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/294.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1034.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/400.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1491.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/531.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/903.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1417.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1482.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1089.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/795.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/278.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/864.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/470.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/13.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/55.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1033.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1407.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/806.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/812.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1098.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/702.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/491.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1075.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1182.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1035.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/373.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/160.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1234.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/8.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/496.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1329.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/608.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/898.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1218.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1191.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1380.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1108.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1443.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/855.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1418.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1130.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/256.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1050.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/288.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1323.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1369.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1239.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1435.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/486.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/88.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/342.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1336.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/73.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/77.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/361.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/935.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/275.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/526.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/57.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/277.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/44.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1390.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1180.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/208.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1415.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/38.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/727.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1127.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/117.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/137.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/235.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1245.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/555.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1400.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/639.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/143.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1106.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1028.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1125.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1282.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1337.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/946.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/156.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/21.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1221.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1080.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/461.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1163.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/755.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/848.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/105.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1357.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/84.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1262.wav',
# ...
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/663.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1304.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/574.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/83.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1334.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/895.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/578.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1271.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/139.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1297.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/982.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/532.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1049.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/231.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1200.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/343.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/166.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1248.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/447.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/709.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/157.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/445.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1490.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/119.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1177.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1062.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1411.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/721.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/172.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/868.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/418.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/537.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/924.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1138.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/561.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/265.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/801.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/443.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1426.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1205.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/871.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/644.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/816.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/564.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/667.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/351.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1484.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/283.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/66.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/528.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1424.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/922.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/597.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/770.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/420.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/179.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/150.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/807.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/244.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/363.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/383.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/921.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1382.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/902.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1386.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/867.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1064.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/331.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/941.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1315.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1017.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1016.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/477.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/31.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1368.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/610.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/803.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/441.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1211.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1428.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1306.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1162.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/742.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1003.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/692.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/435.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1061.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1219.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/623.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/877.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/997.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/759.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/734.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/810.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1476.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1015.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/691.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1257.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/827.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/970.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/686.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/571.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/39.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/585.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/634.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/412.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/516.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/718.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/180.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/422.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/40.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1287.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/919.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/558.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1164.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1243.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1092.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/626.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1214.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/797.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/254.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/415.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1008.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/723.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/110.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1040.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1432.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1473.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1104.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/613.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/839.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/30.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1123.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/584.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/914.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1449.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/270.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1146.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/889.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/227.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/861.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/983.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/892.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/177.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1121.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1039.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/885.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/91.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1409.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1155.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1116.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/994.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/245.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/905.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/752.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/230.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/24.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1019.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/95.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/685.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/421.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1468.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/748.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/878.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1487.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/386.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1270.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/6.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1114.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1145.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1298.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1197.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1230.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1147.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/710.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/656.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1259.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1351.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1052.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/791.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/529.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/971.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1276.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1466.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1367.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/655.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/48.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/937.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1492.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/897.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/382.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/843.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/336.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/680.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/769.wav',
#  'speaker-recognition-dataset/16000_pcm_speeches/audio/Magaret_Tarcher/1046.wav',
#  ...]

# %% [markdown]
# Dataset Generation

# %%
def paths_and_labels_to_dataset(audio_paths, labels, sample_rate):
    def path_to_audio(path, label):
        audio = tf.io.read_file(path)
        audio, _ = tf.audio.decode_wav(audio, 1, sample_rate)
        return audio, label

    path_ds = tf.data.Dataset.from_tensor_slices(audio_paths)
    label_ds = tf.data.Dataset.from_tensor_slices(labels)

    dataset = tf.data.Dataset.zip((path_ds, label_ds))
    dataset = dataset.map(lambda x, y: path_to_audio(x, y))

    return dataset

# %% [markdown]
# Noise Addition

# %%
def add_noise(audio, noises=None, scale=0.5):
    if noises is not None:
        tf_rnd = tf.random.uniform(
            (tf.shape(audio)[0],), 0, noises.shape[0], dtype=tf.int32
        )
        noise = tf.gather(noises, tf_rnd, axis=0)

        prop = tf.math.reduce_max(audio, axis=1) / tf.math.reduce_max(noise, axis=1)
        prop = tf.repeat(tf.expand_dims(prop, axis=1), tf.shape(audio)[1], axis=1)

        audio = audio + noise * prop * scale

    return audio

def audio_to_fft(audio):
    audio = tf.squeeze(audio, axis=-1)
    fft = tf.signal.fft(
        tf.cast(tf.complex(real=audio, imag=tf.zeros_like(audio)), tf.complex64)
    )
    fft = tf.expand_dims(fft, axis=-1)

    return tf.math.abs(fft[:, : (audio.shape[1] // 2), :])

# %%
class_names = os.listdir(audio_path)
print(class_names,)
# Out:
# ['Julia_Gillard', 'Magaret_Tarcher', 'Nelson_Mandela', 'Benjamin_Netanyau', 'Jens_Stoltenberg']

# %%
audio_paths = []
labels = []

for label, name in enumerate(class_names):
    print("Speaker:",(name))
    dir_path = Path(audio_path) / name
    speaker_sample_paths = [
        os.path.join(dir_path, filepath)
        for filepath in os.listdir(dir_path)
        if filepath.endswith(".wav")
    ]

    # Filter speaker_sample_paths based on selected_speaker_files
    filtered_paths = [path for path in speaker_sample_paths if path in selected_speaker_files]

    # Add filtered paths to audio_paths
    audio_paths += filtered_paths

    # Extend labels list with the corresponding label
    labels += [label] * len(filtered_paths)
# Out:
# Speaker: Julia_Gillard
# Speaker: Magaret_Tarcher
# Speaker: Nelson_Mandela
# Speaker: Benjamin_Netanyau
# Speaker: Jens_Stoltenberg

# %%
# Shuffle to generate random data
rng = np.random.RandomState(shuffle_seed)
rng.shuffle(audio_paths)
rng = np.random.RandomState(shuffle_seed)
rng.shuffle(labels)

num_val_samples = int(valid_split * len(audio_paths))
train_audio_paths = audio_paths[:-num_val_samples]
train_labels = labels[:-num_val_samples]


valid_audio_paths = audio_paths[-num_val_samples:]
valid_labels = labels[-num_val_samples:]

train_ds = paths_and_labels_to_dataset(train_audio_paths, train_labels, sample_rate)
train_ds = train_ds.shuffle(buffer_size=batch_size * 8, seed=shuffle_seed).batch(batch_size)

valid_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels, sample_rate)
valid_ds = valid_ds.shuffle(buffer_size=32 * 8, seed=shuffle_seed).batch(32)

# %% [markdown]
# # Feature Extraction

# %%
train_ds = train_ds.map(
    lambda x, y: (add_noise(x, noises, scale=scale), y),
    num_parallel_calls=tf.data.experimental.AUTOTUNE,
)
train_ds = train_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
)

train_ds = train_ds.prefetch(tf.data.experimental.AUTOTUNE)

valid_ds = valid_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
)
valid_ds = valid_ds.prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# # Model

# %%
from tensorflow.keras.layers import Conv1D
def residual_block(x, filters, conv_num = 3, activation = "relu"):
    s = keras.layers.Conv1D(filters, 1, padding = "same")(x)

    for i in range(conv_num - 1):
        x = keras.layers.Conv1D(filters, 3, padding = "same")(x)
        x = keras.layers.Activation(activation)(x)

    x = keras.layers.Conv1D(filters, 3, padding = "same")(x)
    x = keras.layers.Add()([x, s])
    x = keras.layers.Activation(activation)(x)

    return keras.layers.MaxPool1D(pool_size = 2, strides = 2)(x)

def build_model(input_shape, num_classes):
    inputs = keras.layers.Input(shape = input_shape, name = "input")

    x = residual_block(inputs, 16, 2)
    x = residual_block(inputs, 32, 2)
    x = residual_block(inputs, 64, 3)
    x = residual_block(inputs, 128, 3)
    x = residual_block(inputs, 128, 3)
    x = keras.layers.AveragePooling1D(pool_size=3, strides=3)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(256, activation="relu")(x)
    x = keras.layers.Dense(128, activation="relu")(x)

    outputs = keras.layers.Dense(num_classes, activation = "softmax", name = "output")(x)

    return keras.models.Model(inputs = inputs, outputs = outputs)

model = build_model((sample_rate // 2, 1), len(class_names))

model.summary()

model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

model_save_filename = "model.h5"

earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

mdlcheckpoint_cb = keras.callbacks.ModelCheckpoint(model_save_filename, monitor="val_accuracy", save_best_only=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 8000, 1)]            0         []
#
#  conv1d_15 (Conv1D)          (None, 8000, 128)            512       ['input[0][0]']
#
#  activation_10 (Activation)  (None, 8000, 128)            0         ['conv1d_15[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 8000, 128)            49280     ['activation_10[0][0]']
#
#  activation_11 (Activation)  (None, 8000, 128)            0         ['conv1d_16[0][0]']
#
#  conv1d_17 (Conv1D)          (None, 8000, 128)            49280     ['activation_11[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 8000, 128)            256       ['input[0][0]']
#
#  add_4 (Add)                 (None, 8000, 128)            0         ['conv1d_17[0][0]',
#                                                                      'conv1d_14[0][0]']
#
#  activation_12 (Activation)  (None, 8000, 128)            0         ['add_4[0][0]']
#
#  max_pooling1d_4 (MaxPoolin  (None, 4000, 128)            0         ['activation_12[0][0]']
#  g1D)
#
#  average_pooling1d (Average  (None, 1333, 128)            0         ['max_pooling1d_4[0][0]']
#  Pooling1D)
#
#  flatten (Flatten)           (None, 170624)               0         ['average_pooling1d[0][0]']
#
#  dense (Dense)               (None, 256)                  4368000   ['flatten[0][0]']
#                                                           0
#
#  dense_1 (Dense)             (None, 128)                  32896     ['dense[0][0]']
#
#  output (Dense)              (None, 5)                    645       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 43812869 (167.13 MB)
# Trainable params: 43812869 (167.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
history = model.fit(
    train_ds,
    epochs=epochs,
    validation_data=valid_ds,
    callbacks=[earlystopping_cb, mdlcheckpoint_cb],
)
# Out:
# Epoch 1/10
# 36/36 [==============================] - ETA: 0s - loss: 46.1269 - accuracy: 0.3707
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 36/36 [==============================] - 380s 11s/step - loss: 46.1269 - accuracy: 0.3707 - val_loss: 0.9179 - val_accuracy: 0.6640
# Epoch 2/10
# 36/36 [==============================] - 382s 11s/step - loss: 0.6612 - accuracy: 0.7573 - val_loss: 0.4221 - val_accuracy: 0.8880
# Epoch 3/10
# 36/36 [==============================] - 377s 10s/step - loss: 0.2366 - accuracy: 0.9076 - val_loss: 0.2036 - val_accuracy: 0.9320
# Epoch 4/10
# 36/36 [==============================] - 377s 10s/step - loss: 0.1592 - accuracy: 0.9400 - val_loss: 0.1985 - val_accuracy: 0.9120
# Epoch 5/10
# 36/36 [==============================] - 379s 11s/step - loss: 0.1005 - accuracy: 0.9604 - val_loss: 0.1139 - val_accuracy: 0.9600
# Epoch 6/10
# 36/36 [==============================] - 367s 10s/step - loss: 0.1024 - accuracy: 0.9636 - val_loss: 0.2522 - val_accuracy: 0.9440
# Epoch 7/10
# 36/36 [==============================] - 370s 10s/step - loss: 0.1899 - accuracy: 0.9324 - val_loss: 0.1777 - val_accuracy: 0.9200
# Epoch 8/10
# 36/36 [==============================] - 363s 10s/step - loss: 0.1410 - accuracy: 0.9471 - val_loss: 0.1844 - val_accuracy: 0.9320
# Epoch 9/10
# 36/36 [==============================] - 374s 10s/step - loss: 0.0901 - accuracy: 0.9676 - val_loss: 0.2049 - val_accuracy: 0.9520
# Epoch 10/10
# 36/36 [==============================] - 371s 10s/step - loss: 0.0956 - accuracy: 0.9662 - val_loss: 0.1756 - val_accuracy: 0.9480

# %% [markdown]
# # Accuracy

# %%
print("Accuracy of model:",model.evaluate(valid_ds))
# Out:
# 8/8 [==============================] - 11s 1s/step - loss: 0.1756 - accuracy: 0.9480
# Accuracy of model: [0.1756058931350708, 0.9480000138282776]

# %% [markdown]
# # Testing

# %%
SAMPLES_TO_DISPLAY = 10

test_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels, sample_rate)
test_ds = test_ds.shuffle(buffer_size=32 * 8, seed=shuffle_seed).batch(batch_size)


test_ds = test_ds.map(lambda x, y: (add_noise(x, noises, scale=scale), y))

for audios, labels in test_ds.take(1):
    ffts = audio_to_fft(audios)
    y_pred = model.predict(ffts)
    rnd = np.random.randint(0, batch_size, SAMPLES_TO_DISPLAY)
    audios = audios.numpy()[rnd, :, :]
    labels = labels.numpy()[rnd]
    y_pred = np.argmax(y_pred, axis=-1)[rnd]

    for index in range(SAMPLES_TO_DISPLAY):
        print(
            "Speaker:\33{} {}\33[0m\tPredicted:\33{} {}\33[0m".format(
                "[92m" if labels[index] == y_pred[index] else "[91m",
                class_names[labels[index]],
                "[92m" if labels[index] == y_pred[index] else "[91m",
                class_names[y_pred[index]],
            )
        )
        if labels[index] ==y_pred[index]:
            print("Welcome")
        else:
            print("Sorry")
        print("The speaker is" if labels[index] == y_pred[index] else "", class_names[y_pred[index]])
# Out:
# 2/2 [==============================] - 4s 1s/step
# Speaker: Benjamin_Netanyau	Predicted: Benjamin_Netanyau
# Welcome
# The speaker is Benjamin_Netanyau
# Speaker: Jens_Stoltenberg	Predicted: Jens_Stoltenberg
# Welcome
# The speaker is Jens_Stoltenberg
# Speaker: Jens_Stoltenberg	Predicted: Jens_Stoltenberg
# Welcome
# The speaker is Jens_Stoltenberg
# Speaker: Nelson_Mandela	Predicted: Nelson_Mandela
# Welcome
# The speaker is Nelson_Mandela
# Speaker: Julia_Gillard	Predicted: Julia_Gillard
# Welcome
# The speaker is Julia_Gillard
# Speaker: Julia_Gillard	Predicted: Julia_Gillard
# Welcome
# The speaker is Julia_Gillard
# Speaker: Julia_Gillard	Predicted: Julia_Gillard
# Welcome
# The speaker is Julia_Gillard
# Speaker: Magaret_Tarcher	Predicted: Magaret_Tarcher
# Welcome
# The speaker is Magaret_Tarcher
# Speaker: Julia_Gillard	Predicted: Julia_Gillard
# Welcome
# The speaker is Julia_Gillard
# Speaker: Nelson_Mandela	Predicted: Nelson_Mandela
# Welcome
# The speaker is Nelson_Mandela

# %% [markdown]
# # Real Time prediction

# %%
def predict(path, labels):
    # Extract the speaker label from the path
    speaker_label = os.path.basename(os.path.dirname(path[0]))

    # Get the index of the speaker label in the class_names list
    label_index = class_names.index(speaker_label)

    # Assign the integer label to the labels list
    labels = [label_index]

    # Create the test dataset
    test = paths_and_labels_to_dataset(path, labels, sample_rate)

    test = test.shuffle(buffer_size=batch_size * 8, seed=shuffle_seed).batch(batch_size)
    test = test.prefetch(tf.data.experimental.AUTOTUNE)
    test = test.map(lambda x, y: (add_noise(x, noises, scale=scale), y))

    for audios, labels in test.take(1):
        ffts = audio_to_fft(audios)
        y_pred = model.predict(ffts)
        rnd = np.random.randint(0, len(audios), 1)
        audios = audios.numpy()[rnd, :, :]
        labels = labels.numpy()[rnd]
        y_pred = np.argmax(y_pred, axis=-1)[rnd]
        for index in range(1):
            print(
                "Speaker:\33{} {}\33[0m\tPredicted:\33{} {}\33[0m".format(
                    "[92m", class_names[labels[index]],
                    "[92m", class_names[y_pred[index]]
                )
            )
            print("Speaker Predicted:", class_names[y_pred[index]])

path = ["./speaker-recognition-dataset/16000_pcm_speeches/Nelson_Mandela/33.wav"]
labels = [0]  # Assuming "unknown" corresponds to class index 0

try:
    predict(path, labels)
except:
    print("Error! Check if the file correctly passed or not!")
# Out:
# 1/1 [==============================] - 0s 76ms/step
# Speaker: Nelson_Mandela	Predicted: Nelson_Mandela
# Speaker Predicted: Nelson_Mandela
